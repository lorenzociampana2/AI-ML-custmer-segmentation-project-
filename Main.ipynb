# %%
from sklearn.metrics import silhouette_score
from pandas.plotting import parallel_coordinates
from sklearn.cluster import DBSCAN
from sklearn.neighbors import NearestNeighbors
from sklearn.cluster import AgglomerativeClustering
import scipy.cluster.hierarchy as sch
from sklearn.metrics import davies_bouldin_score
from sklearn.metrics import calinski_harabasz_score
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns       
from sklearn.decomposition import PCA

# %%
data = pd.read_csv('customer_segmentation.csv')

# %%
data.head()
# Out:
#                            order_id                       customer_id  \
# 0  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 1  86674ccaee19790309333210917b2c7d  1b338293f35549b5e480b9a3d7bbf3cd
# 2  aee682982e18eb4714ce9f97b15af5e2  8858442ea4d5dc5bb9e118e8f728095d
# 3  d543201a9b42a1402ff97e65b439a48b  971bf8f42a9f8cb3ead257854905b454
# 4  d543201a9b42a1402ff97e65b439a48b  971bf8f42a9f8cb3ead257854905b454
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 1    delivered      2018-08-09 11:37:35  2018-08-09 14:35:19
# 2    delivered      2018-07-09 18:46:28  2018-07-11 03:45:45
# 3    delivered      2018-08-21 10:00:25  2018-08-21 10:50:54
# 4    delivered      2018-08-21 10:00:25  2018-08-21 10:50:54
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2018-07-26 14:31:00           2018-08-07 15:27:45
# 1          2018-08-10 14:34:00           2018-08-14 18:51:47
# 2          2018-07-11 15:01:00           2018-07-12 18:14:35
# 3          2018-08-22 15:21:00           2018-08-28 18:58:22
# 4          2018-08-22 15:21:00           2018-08-28 18:58:22
#
#   order_estimated_delivery_date payment_type  payment_installments  ...  \
# 0           2018-08-13 00:00:00       boleto                     1  ...
# 1           2018-08-22 00:00:00  credit_card                     5  ...
# 2           2018-07-18 00:00:00       boleto                     1  ...
# 3           2018-09-10 00:00:00  credit_card                     2  ...
# 4           2018-09-10 00:00:00  credit_card                     2  ...
#
#                           seller_id  shipping_limit_date  price freight_value  \
# 0  289cdb325fb7e7f891c38608bf9e0962  2018-07-30 03:24:27  118.7         22.76
# 1  289cdb325fb7e7f891c38608bf9e0962  2018-08-13 14:31:29  116.9         18.92
# 2  289cdb325fb7e7f891c38608bf9e0962  2018-07-13 03:45:45  118.7          9.34
# 3  289cdb325fb7e7f891c38608bf9e0962  2018-08-23 10:50:54  116.9         22.75
# 4  289cdb325fb7e7f891c38608bf9e0962  2018-08-23 10:50:54  116.9         22.75
#
#       seller_city seller_state product_category_name product_name_lenght  \
# 0  belo horizonte           SP            perfumaria                  29
# 1  belo horizonte           SP            perfumaria                  29
# 2  belo horizonte           SP            perfumaria                  29
# 3  belo horizonte           SP            perfumaria                  29
# 4  belo horizonte           SP            perfumaria                  29
#
#    product_description_lenght  product_category_name_english
# 0                         178                      perfumery
# 1                         178                      perfumery
# 2                         178                      perfumery
# 3                         178                      perfumery
# 4                         178                      perfumery
#
# [5 rows x 26 columns]

# %%
dates = ['order_purchase_timestamp', 'order_approved_at', 'order_approved_at', 'order_delivered_carrier_date',
            'order_delivered_customer_date', 'order_estimated_delivery_date', 'shipping_limit_date']

# %% [markdown]
# CONVERTING THE VARIABLES INTO DATE BY USING PANDAS:

# %%
for i in dates:
    data[i] = pd.to_datetime(data[i])

# %%
data
# Out:
#                                order_id                       customer_id  \
# 0      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 1      86674ccaee19790309333210917b2c7d  1b338293f35549b5e480b9a3d7bbf3cd
# 2      aee682982e18eb4714ce9f97b15af5e2  8858442ea4d5dc5bb9e118e8f728095d
# 3      d543201a9b42a1402ff97e65b439a48b  971bf8f42a9f8cb3ead257854905b454
# 4      d543201a9b42a1402ff97e65b439a48b  971bf8f42a9f8cb3ead257854905b454
# ...                                 ...                               ...
# 13796  493ba21a937e956c5e0e4e26c9f1b7f9  408d74d06be5d5140bb933f248de1342
# 13797  4a7cf245701068d38d441791b735e4bd  1d3b24ba06f2e3fa4bfa74fd70d2310f
# 13798  33f8dfc5a51063c31d7b12e9d43a45fc  8f7f4871646eb2fa410cc2d50b861317
# 13799  442a41b00a8a8bda35511fdf1eb65cc5  e42e2e8642f9c09100b6667e321c2811
# 13800  73d60420cd1a179b2d8887d538efe4c2  65d9213dfa004c17dc126503e106e4a3
#
#       order_status order_purchase_timestamp   order_approved_at  \
# 0        delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 1        delivered      2018-08-09 11:37:35 2018-08-09 14:35:19
# 2        delivered      2018-07-09 18:46:28 2018-07-11 03:45:45
# 3        delivered      2018-08-21 10:00:25 2018-08-21 10:50:54
# 4        delivered      2018-08-21 10:00:25 2018-08-21 10:50:54
# ...            ...                      ...                 ...
# 13796    delivered      2018-07-15 09:56:32 2018-07-16 13:30:36
# 13797    delivered      2018-05-07 20:36:47 2018-05-07 20:51:50
# 13798    delivered      2018-04-28 14:32:54 2018-04-28 14:53:18
# 13799     invoiced      2018-07-11 22:27:32 2018-07-11 22:45:43
# 13800    delivered      2018-08-07 10:52:58 2018-08-07 11:05:18
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 0              2018-07-26 14:31:00           2018-08-07 15:27:45
# 1              2018-08-10 14:34:00           2018-08-14 18:51:47
# 2              2018-07-11 15:01:00           2018-07-12 18:14:35
# 3              2018-08-22 15:21:00           2018-08-28 18:58:22
# 4              2018-08-22 15:21:00           2018-08-28 18:58:22
# ...                            ...                           ...
# 13796          2018-07-27 07:26:00           2018-08-02 18:06:41
# 13797          2018-05-08 15:04:00           2018-05-09 22:38:53
# 13798          2018-05-02 15:25:00           2018-05-03 23:51:56
# 13799          2018-07-11 22:45:43           2018-07-20 00:00:00
# 13800          2018-08-08 08:31:00           2018-08-22 17:02:23
#
#       order_estimated_delivery_date payment_type  payment_installments  ...  \
# 0                        2018-08-13       boleto                     1  ...
# 1                        2018-08-22  credit_card                     5  ...
# 2                        2018-07-18       boleto                     1  ...
# 3                        2018-09-10  credit_card                     2  ...
# 4                        2018-09-10  credit_card                     2  ...
# ...                             ...          ...                   ...  ...
# 13796                    2018-07-26       boleto                     1  ...
# 13797                    2018-05-17  credit_card                     1  ...
# 13798                    2018-05-14  credit_card                     1  ...
# 13799                    2018-07-20  credit_card                     1  ...
# 13800                    2018-09-04  credit_card                    10  ...
#
#                               seller_id shipping_limit_date   price  \
# 0      289cdb325fb7e7f891c38608bf9e0962 2018-07-30 03:24:27  118.70
# 1      289cdb325fb7e7f891c38608bf9e0962 2018-08-13 14:31:29  116.90
# 2      289cdb325fb7e7f891c38608bf9e0962 2018-07-13 03:45:45  118.70
# 3      289cdb325fb7e7f891c38608bf9e0962 2018-08-23 10:50:54  116.90
# 4      289cdb325fb7e7f891c38608bf9e0962 2018-08-23 10:50:54  116.90
# ...                                 ...                 ...     ...
# 13796  7c5b05cbdb5542049f38d90d7815b97d 2018-07-20 13:30:36   19.99
# 13797  7c5b05cbdb5542049f38d90d7815b97d 2018-05-11 20:51:50   18.99
# 13798  7c5b05cbdb5542049f38d90d7815b97d 2018-05-04 14:53:18   18.99
# 13799  7c5b05cbdb5542049f38d90d7815b97d 2018-07-16 22:45:43   44.99
# 13800  9b1585752613ec342d03bbab9997ec48 2018-08-13 11:05:18  749.00
#
#       freight_value     seller_city seller_state product_category_name  \
# 0             22.76  belo horizonte           SP            perfumaria
# 1             18.92  belo horizonte           SP            perfumaria
# 2              9.34  belo horizonte           SP            perfumaria
# 3             22.75  belo horizonte           SP            perfumaria
# 4             22.75  belo horizonte           SP            perfumaria
# ...             ...             ...          ...                   ...
# 13796          7.40       sao paulo           SP     livros_importados
# 13797          7.39       sao paulo           SP     livros_importados
# 13798          7.39       sao paulo           SP     livros_importados
# 13799          7.58       sao paulo           SP     livros_importados
# 13800         55.96  rio de janeiro           RJ     livros_importados
#
#       product_name_lenght  product_description_lenght  \
# 0                      29                         178
# 1                      29                         178
# 2                      29                         178
# 3                      29                         178
# 4                      29                         178
# ...                   ...                         ...
# 13796                  53                          80
# 13797                  53                          80
# 13798                  53                          80
# 13799                  53                         568
# 13800                  57                        3694
#
#        product_category_name_english
# 0                          perfumery
# 1                          perfumery
# 2                          perfumery
# 3                          perfumery
# 4                          perfumery
# ...                              ...
# 13796                 books_imported
# 13797                 books_imported
# 13798                 books_imported
# 13799                 books_imported
# 13800                 books_imported
#
# [13801 rows x 26 columns]

# %% [markdown]
# WE CAN ALSO DISTINCT DATE FROM TIME:

# %%
data['order_date'] = [d.date() for d in data['order_purchase_timestamp']]
data['order_time'] = [d.time() for d in data['order_purchase_timestamp']]

# %%
data.tail()
# Out:
#                                order_id                       customer_id  \
# 13796  493ba21a937e956c5e0e4e26c9f1b7f9  408d74d06be5d5140bb933f248de1342
# 13797  4a7cf245701068d38d441791b735e4bd  1d3b24ba06f2e3fa4bfa74fd70d2310f
# 13798  33f8dfc5a51063c31d7b12e9d43a45fc  8f7f4871646eb2fa410cc2d50b861317
# 13799  442a41b00a8a8bda35511fdf1eb65cc5  e42e2e8642f9c09100b6667e321c2811
# 13800  73d60420cd1a179b2d8887d538efe4c2  65d9213dfa004c17dc126503e106e4a3
#
#       order_status order_purchase_timestamp   order_approved_at  \
# 13796    delivered      2018-07-15 09:56:32 2018-07-16 13:30:36
# 13797    delivered      2018-05-07 20:36:47 2018-05-07 20:51:50
# 13798    delivered      2018-04-28 14:32:54 2018-04-28 14:53:18
# 13799     invoiced      2018-07-11 22:27:32 2018-07-11 22:45:43
# 13800    delivered      2018-08-07 10:52:58 2018-08-07 11:05:18
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 13796          2018-07-27 07:26:00           2018-08-02 18:06:41
# 13797          2018-05-08 15:04:00           2018-05-09 22:38:53
# 13798          2018-05-02 15:25:00           2018-05-03 23:51:56
# 13799          2018-07-11 22:45:43           2018-07-20 00:00:00
# 13800          2018-08-08 08:31:00           2018-08-22 17:02:23
#
#       order_estimated_delivery_date payment_type  payment_installments  ...  \
# 13796                    2018-07-26       boleto                     1  ...
# 13797                    2018-05-17  credit_card                     1  ...
# 13798                    2018-05-14  credit_card                     1  ...
# 13799                    2018-07-20  credit_card                     1  ...
# 13800                    2018-09-04  credit_card                    10  ...
#
#         price freight_value     seller_city seller_state  \
# 13796   19.99          7.40       sao paulo           SP
# 13797   18.99          7.39       sao paulo           SP
# 13798   18.99          7.39       sao paulo           SP
# 13799   44.99          7.58       sao paulo           SP
# 13800  749.00         55.96  rio de janeiro           RJ
#
#        product_category_name product_name_lenght product_description_lenght  \
# 13796      livros_importados                  53                         80
# 13797      livros_importados                  53                         80
# 13798      livros_importados                  53                         80
# 13799      livros_importados                  53                        568
# 13800      livros_importados                  57                       3694
#
#       product_category_name_english  order_date  order_time
# 13796                books_imported  2018-07-15    09:56:32
# 13797                books_imported  2018-05-07    20:36:47
# 13798                books_imported  2018-04-28    14:32:54
# 13799                books_imported  2018-07-11    22:27:32
# 13800                books_imported  2018-08-07    10:52:58
#
# [5 rows x 28 columns]

# %%
data.shape
# Out:
# (13801, 28)

# %%
data.describe()  #Dataset visualization with all the values
# Out:
#        payment_installments  payment_value  order_item_id         price  \
# count          13801.000000   13801.000000   13801.000000  13801.000000
# mean               3.014637     194.349691       1.230491    130.947103
# std                2.801721     294.854258       0.737495    210.712421
# min                1.000000       0.050000       1.000000      0.850000
# 25%                1.000000      66.750000       1.000000     40.000000
# 50%                2.000000     120.290000       1.000000     79.000000
# 75%                4.000000     206.780000       1.000000    139.000000
# max               20.000000    7274.880000      13.000000   4590.000000
#
#        freight_value  product_name_lenght  product_description_lenght
# count   13801.000000         13801.000000                13801.000000
# mean       21.938168            49.300703                  814.330411
# std        18.567013             9.759529                  648.790194
# min         0.000000             8.000000                    4.000000
# 25%        12.870000            43.000000                  366.000000
# 50%        18.230000            52.000000                  631.000000
# 75%        23.310000            57.000000                 1030.000000
# max       375.280000            69.000000                 3985.000000

# %%
data.columns  #Columns of the dataset
# Out:
# Index(['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp',
#        'order_approved_at', 'order_delivered_carrier_date',
#        'order_delivered_customer_date', 'order_estimated_delivery_date',
#        'payment_type', 'payment_installments', 'payment_value',
#        'customer_unique_id', 'customer_city', 'customer_state',
#        'order_item_id', 'product_id', 'seller_id', 'shipping_limit_date',
#        'price', 'freight_value', 'seller_city', 'seller_state',
#        'product_category_name', 'product_name_lenght',
#        'product_description_lenght', 'product_category_name_english',
#        'order_date', 'order_time'],
#       dtype='object')

# %%
data.nunique()  #The output of number of unique values is returned
# Out:
# order_id                         11394
# customer_id                      11394
# order_status                         5
# order_purchase_timestamp         11361
# order_approved_at                10759
# order_delivered_carrier_date      8851
# order_delivered_customer_date    11161
# order_estimated_delivery_date      156
# payment_type                         4
# payment_installments                19
# payment_value                     7764
# customer_unique_id               11247
# customer_city                     1728
# customer_state                      27
# order_item_id                       13
# product_id                        6915
# seller_id                         1616
# shipping_limit_date              11228
# price                             2092
# freight_value                     3319
# seller_city                        395
# seller_state                        18
# product_category_name               66
# product_name_lenght                 56
# product_description_lenght        1951
# product_category_name_english       66
# order_date                         208
# order_time                       10399
# dtype: int64

# %%
data['order_id'].unique()
# Out:
# array(['53cdb2fc8bc7dce0b6741e2150273451',
#        '86674ccaee19790309333210917b2c7d',
#        'aee682982e18eb4714ce9f97b15af5e2', ...,
#        '33f8dfc5a51063c31d7b12e9d43a45fc',
#        '442a41b00a8a8bda35511fdf1eb65cc5',
#        '73d60420cd1a179b2d8887d538efe4c2'], dtype=object)

# %%
data['seller_city'].unique()
# Out:
# array(['belo horizonte', 'sao goncalo', 'limeira', 'santo andre',
#        'ribeirao preto', 'brasilia', 'mococa', 'campinas', 'sao paulo',
#        'praia grande', 'salto', 'rio de janeiro', 'betim', 'apucarana',
#        'umuarama', 'petropolis', 'videira', 'presidente prudente',
#        'novo hamburgo', 'congonhal', 'taboao da serra', 'araucaria',
#        'indaiatuba', 'riberao preto', 'sao  paulo', 'birigui', 'criciuma',
#        'navegantes', 'carapicuiba', 'vicente de carvalho', 'guaruja',
#        'sinop', 'bauru', 'suzano', 'mogi das cruzes', 'valinhos',
#        'nova friburgo', 'guarulhos', 'extrema', 'santa catarina',
#        'lagoa da prata', 'campos dos goytacazes', 'morrinhos', 'atibaia',
#        'franca', 'londrina', 'mogi mirim', 'sao carlos', 'curitiba',
#        'ponta grossa', 'campo mourao', 'americana', 'itajai',
#        'santo andre/sao paulo', 'sao bernardo do campo', 'bombinhas',
#        'teresopolis', 'piracicaba', 'hortolandia', 'santos',
#        'sao jose do rio preto', 'ribeirao preto / sao paulo', 'jacarei',
#        'formiga', 'sao sebastiao', 'jundiai', 'sao luis', 'jau',
#        'echapora', 'carapicuiba / sao paulo', 'ipaussu', 'sumare',
#        'fronteira', 'assis', 'ribeirao pires', 'diadema', 'sando andre',
#        'botucatu', 'maringa', 'sao jose dos campos', 'cascavel', 'araras',
#        'nova iguacu', 'lencois paulista', 'sao jose dos pinhais',
#        'mirassol', 'fortaleza', 'goiania', 'ipatinga', 'cotia', 'itu',
#        'conselheiro lafaiete', 'itaporanga', 'varzea paulista', 'cuiaba',
#        'engenheiro coelho', 'sao joao del rei', 'santo antonio de padua',
#        'mineiros do tiete', 'arapongas', 'sao paulo - sp', 'santo angelo',
#        'sorocaba', 'rio claro', 'bom jardim', 'venancio aires',
#        'itaquaquecetuba', 'marechal candido rondon', 'guanhaes',
#        'itapeva', 'artur nogueira', 'indaial', 'mesquita', 'pitanga',
#        'clementina', 'treze tilias', 'niteroi', 'cianorte', 'goioere',
#        'irati', 'palhoca', 'volta redonda', 'contagem', 'canoas',
#        'pedrinhas paulista', 'triunfo', 'santana de parnaiba', 'picarras',
#        "santa barbara d'oeste", 'osasco', 'toledo', 'vassouras',
#        'jaragua do sul', 'guariba', 'pradopolis', 'colombo',
#        'campo limpo paulista', 'barueri', 'serra negra', 'blumenau',
#        'mamanguape', 'registro', 'queimados', 'orleans', 'ibitinga',
#        'itatiba', 'jaboticabal', 'capivari', 'macae', 'porto alegre',
#        'montenegro', 'santa rita do sapucai', 'recife', 'araraquara',
#        'braco do norte', 'franco da rocha', 'sete lagoas', 'bertioga',
#        'mogi das cruses', 'lauro de freitas', 'pilar do sul',
#        'uberlandia', 'itapecerica da serra', 'taubate', 'guanambi',
#        'balneario camboriu', 'campo bom', 'fazenda rio grande',
#        'joinville', 'marilia', 'cajamar', 'alvorada', 'serrana',
#        'itapevi', 'salvador', 'cachoeiro de itapemirim', 'joao pessoa',
#        'juiz de fora', 'icara', 'penapolis', 'cafelandia',
#        'patos de minas', 'buritama', 'mogi guacu',
#        'vargem grande paulista', 'dois corregos', 'mandirituba',
#        'imbituba', 'dores de campos', 'santo antonio de posse',
#        'porto belo', 'ipua', 'florianopolis', 'cruzeiro', 'tubarao',
#        'bebedouro', 'paulinia', 'sao bento do sul', 'alfenas',
#        'votorantim', 'nilopolis', 'caxias do sul', 'campo do meio',
#        'anapolis', 'ponte nova', 'braganca paulista', 'rio verde',
#        'divinopolis', 'sao roque', 'teresina', 'rolandia',
#        'angra dos reis', 'coxim', 'garca', 'nova odessa',
#        'sao caetano do sul', 'japira', 'barretos', 'sao paluo',
#        'vargem grande do sul', 'mairipora',
#        'novo hamburgo, rio grande do sul, brasil', 'araguari',
#        'laranjal paulista', 'tatui', 'descalvado', 'bocaiuva do sul',
#        'uba', 'coronel fabriciano', 'guaratuba', 'irece',
#        'duque de caxias', 'lorena', 'rio de janeiro \\rio de janeiro',
#        'cordilheira alta', 'tabatinga', 'borda da mata', 'sao ludgero',
#        'carazinho', 'maua', 'varginha', 'tabao da serra', 'sp / sp',
#        'sao joao de meriti', 'socorro', 'cariacica', 'ilicinea',
#        'pedreira', 'poa', 'vila velha', 'sp', 'lages', 'jacutinga',
#        'sao pedro', 'vitoria', 'sao leopoldo', 'rio do sul', 'rio grande',
#        'pompeia', 'pinhais', 'cataguases', 'monte siao',
#        'pocos de caldas', 'amparo', 'rio do oeste', 'campo largo',
#        'parana', 'santa barbara d oeste', 'guara', 'claudio',
#        'igaracu do tiete', 'rio bonito', 'sao joaquim da barra',
#        'cornelio procopio', 'tres coracoes', 'votuporanga',
#        'foz do iguacu', 'floresta', 'pirituba', 'ferraz de  vasconcelos',
#        'timbo', 'curitibanos', 'fernandopolis', 'california', 'castro',
#        'ipira', 'estancia velha', 'domingos martins', 'chapeco',
#        'jaguariuna', 'porto ferreira', 'natal', 'jaguaruna', 'vespasiano',
#        'mirandopolis', 'cachoeirinha', 'ferraz de vasconcelos', 'jales',
#        'auriflama', 'tiradentes', 'andira-pr', 'nova lima',
#        'sao pedro da aldeia', 'laurentino', 'formosa do oeste',
#        'varzea alegre', 'tres rios', 'santa barbara d´oeste', 'brusque',
#        'sao bento', 'sao jose', 'muriae', 'lambari',
#        'sao jose dos pinhas', 'itirapina', "sao miguel d'oeste", 'ibia',
#        'bonfinopolis de minas', 'teixeira soares', 'massaranduba',
#        'nova petropolis', 'montes claros', 'loanda',
#        'sao joao da boa vista', 'sarandi', 'vendas@creditparts.com.br',
#        'brejao', 'congonhas', 'bento goncalves', 'embu guacu',
#        'catanduva', 'parai', 'paraiba do sul', 'ilheus',
#        'fernando prestes', 'aracatuba', 'barra mansa',
#        'jacarei / sao paulo', 'rio de janeiro / rio de janeiro',
#        'maua/sao paulo', 'aruja', 'dracena', 'louveira', 'tanabi',
#        'baependi', 'pinhalao', 'concordia', 'ampere', 'campina grande',
#        'camanducaia', 'lagoa santa', 'arvorezinha', 'portao',
#        'rio negrinho', 'colorado', 'sbc/sp', 'garulhos', 'bandeirantes',
#        'francisco beltrao', 'guaira', 'paulo lopes', 'luiz alves',
#        'sao paulo / sao paulo', 'tupa', 'novo horizonte', 'barra velha',
#        'batatais', 'monteiro lobato', 'santa terezinha de itaipu',
#        'bahia', 'sbc', 'bady bassitt', 'vicosa', 'leme', 'santa rosa',
#        'cambe', 'porto seguro', 'gama', 'marica', 'juzeiro do norte',
#        'conchal', 'mandaguacu', 'pedregulho', 'monte alegre do sul',
#        'uruacu', 'messias targino', 'timoteo', 'osvaldo cruz',
#        'flores da cunha', 'auriflama/sp', 'ronda alta', 'aparecida',
#        'mombuca', 'lajeado', 'jaciara'], dtype=object)

# %%
data.isnull().sum()  #The sum of th enull values for each variable
# Out:
# order_id                         0
# customer_id                      0
# order_status                     0
# order_purchase_timestamp         0
# order_approved_at                0
# order_delivered_carrier_date     0
# order_delivered_customer_date    0
# order_estimated_delivery_date    0
# payment_type                     0
# payment_installments             0
# payment_value                    0
# customer_unique_id               0
# customer_city                    0
# customer_state                   0
# order_item_id                    0
# product_id                       0
# seller_id                        0
# shipping_limit_date              0
# price                            0
# freight_value                    0
# seller_city                      0
# seller_state                     0
# product_category_name            0
# product_name_lenght              0
# product_description_lenght       0
# product_category_name_english    0
# order_date                       0
# order_time                       0
# dtype: int64

# %% [markdown]
# WE CAN REMOVE THE DUPLICATES

# %%
data.duplicated().sum()
data.drop_duplicates(keep='first', inplace=True)
data.reset_index(drop=True, inplace=True)  #resetting the index of the dataframe

# %% [markdown]
# OUTLIERS ANALYSIS

# %%
plt.figure()
data.reset_index().plot(kind='scatter', x='index',
                      y='payment_installments', c='brown')

plt.figure() 
data.reset_index().plot(kind='scatter', x='index', y='payment_value', c='gray')

plt.figure()
data.reset_index().plot(kind='scatter', x='index', y='price', c='orange')

plt.figure()
data.reset_index().plot(kind='scatter', x='index', y='freight_value', c='purple')
plt.figure()

# %% [markdown]
# We analyze the 'payment_value' variable because in our mind is one of the most interesting and important variable to study for a big store store like the one in our case. Since it seems having some values that exceed the average, we can suppose that there are some customers who have paid an amount of money which is relatively higher than the other and this can affect our analysis in the future.

# %%
mean_pv = data["payment_value"].mean()  #result mean = 195
std_pv = data["payment_value"].std()    #result Standard Deviation = 295.5
print(mean_pv)
print(std_pv)
# Out:
# 195.20144627496734
# 295.4593435200087

# %% [markdown]
# Taking a look at the scatterplot of the outliers, we can notice that there are few payments above (around) 3500$, so we want as an output all the payments above that amount:

# %%
outlier1 = data[data['payment_value'] > 3500]
print('\nOutlier dataframe:\n', outlier1)

#the output will be 5 payments, each one with all its attributes.
# Out:
# Outlier dataframe:
#                                 order_id                       customer_id  \
# 11673  736e1922ae60d0d6a89247b851902527  ec5b2ba62e574342386871631fafd3fc
# 11674  736e1922ae60d0d6a89247b851902527  ec5b2ba62e574342386871631fafd3fc
# 11675  736e1922ae60d0d6a89247b851902527  ec5b2ba62e574342386871631fafd3fc
# 11676  736e1922ae60d0d6a89247b851902527  ec5b2ba62e574342386871631fafd3fc
# 13638  8dbc85d1447242f3b127dda390d56e19  3d979689f636322c62418b6346b1c6d2
#
#       order_status order_purchase_timestamp   order_approved_at  \
# 11673    delivered      2018-07-15 14:49:44 2018-07-17 04:31:36
# 11674    delivered      2018-07-15 14:49:44 2018-07-17 04:31:36
# 11675    delivered      2018-07-15 14:49:44 2018-07-17 04:31:36
# 11676    delivered      2018-07-15 14:49:44 2018-07-17 04:31:36
# 13638    delivered      2018-06-22 12:23:19 2018-06-22 12:36:36
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 11673          2018-07-20 13:09:00           2018-07-26 22:03:06
# 11674          2018-07-20 13:09:00           2018-07-26 22:03:06
# 11675          2018-07-20 13:09:00           2018-07-26 22:03:06
# 11676          2018-07-20 13:09:00           2018-07-26 22:03:06
# 13638          2018-06-22 13:00:00           2018-07-06 01:08:30
#
#       order_estimated_delivery_date payment_type  payment_installments  ...  \
# 11673                    2018-08-02       boleto                     1  ...
# 11674                    2018-08-02       boleto                     1  ...
# 11675                    2018-08-02       boleto                     1  ...
# 11676                    2018-08-02       boleto                     1  ...
# 13638                    2018-07-17  credit_card                     8  ...
#
#         price freight_value seller_city seller_state  product_category_name  \
# 11673  1790.0         28.72   sao paulo           SP         telefonia_fixa
# 11674  1790.0         28.72   sao paulo           SP         telefonia_fixa
# 11675  1790.0         28.72   sao paulo           SP         telefonia_fixa
# 11676  1790.0         28.72   sao paulo           SP         telefonia_fixa
# 13638  4590.0         91.78    guanambi           BA                    pcs
#
#       product_name_lenght product_description_lenght  \
# 11673                  34                       1016
# 11674                  34                       1016
# 11675                  34                       1016
# 11676                  34                       1016
# 13638                  55                       1710
#
#       product_category_name_english  order_date  order_time
# 11673               fixed_telephony  2018-07-15    14:49:44
# 11674               fixed_telephony  2018-07-15    14:49:44
# 11675               fixed_telephony  2018-07-15    14:49:44
# 11676               fixed_telephony  2018-07-15    14:49:44
# 13638                     computers  2018-06-22    12:23:19
#
# [5 rows x 28 columns]

# %% [markdown]
# We now delete those outliers as they're not relevant for out analysis:

# %%
data = data.drop(data[data.payment_value > 3500].index)
data = data.reset_index(drop=True)

# %% [markdown]
# RELATIONSHOP ANALYSIS:

# %% [markdown]
# CORRELATION:

# %%
correlation = data.corr()

# %% [markdown]
# We can print an heatmap matrix in order to visualize clearly the correlation between each couple of variables:

# %%
sns.heatmap(correlation, xticklabels = correlation.columns, yticklabels = correlation.columns, annot = True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(data)  #This method allows us allows us to plot pairwise relationships between variables within a large dataset dataset like ours, so that we can visualize everything in one figure.

# %%
sns.relplot(x = 'order_item_id', y = 'payment_type', hue = 'customer_state', data = data)

# %%
sns.distplot(data['price'])  #Seaborn Distplot represents the overall distribution of continuous data variables.
# Out:
# /Users/albert/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %% [markdown]
# WHERE DO MOST CUSTOMERS COME FROM?

# %%
state_data = data.groupby('customer_state').count()['customer_id'].reset_index()
city_data = data.groupby('customer_city').count()['customer_id'].reset_index()

plt.figure(figsize = (25,7))

plt.subplot(121)
base_color = sns.color_palette()[0]

sns.barplot(data = state_data.sort_values('customer_id', ascending = False), x = 'customer_state', y = 'customer_id', color = base_color)
plt.title('Number of Customers Per State')
plt.xlabel('State')
plt.ylabel('Number of Customers')

plt.subplot(122)
base_color = sns.color_palette()[0]

sns.barplot(data = city_data.sort_values('customer_id', ascending = False).nlargest(10,'customer_id'), x = 'customer_id', y = 'customer_city', color = base_color)
plt.title('Cities with the Most Customers')
plt.xlabel('City')
plt.ylabel('Number of Customers');

# %% [markdown]
# Here we can see that the state with the higher amount of customers is SP, while the city is Sao Paulo

# %% [markdown]
# WHAT ARE THE MOST FREQUENT ITEMS BOUGHT?

# %%
best_seller_p = data['product_category_name_english'].value_counts(
).reset_index().nlargest(10, 'product_category_name_english')
worst_seller_p = data['product_category_name_english'].value_counts(
).reset_index().nsmallest(10, 'product_category_name_english')
print(best_seller_p)
print(worst_seller_p)
# Out:
#                    index  product_category_name_english
# 0         bed_bath_table                           1386
# 1          health_beauty                           1382
# 2             housewares                           1121
# 3          watches_gifts                           1080
# 4         sports_leisure                            881
# 5  computers_accessories                            850
# 6        furniture_decor                            839
# 7                   auto                            662
# 8              telephony                            514
# 9           garden_tools                            425
#                         index  product_category_name_english
# 62  fashion_childrens_clothes                              1
# 63          cds_dvds_musicals                              1
# 64     tablets_printing_image                              1
# 65                    flowers                              1
# 61               dvds_blu_ray                              3
# 60             home_comfort_2                              4
# 59             books_imported                              6
# 57      arts_and_craftmanship                              8
# 58        diapers_and_hygiene                              8
# 55      fashion_male_clothing                              9

# %% [markdown]
# TOP 10 items bought:

# %%
plt.subplot(211)
sns.barplot(data = best_seller_p, x = 'product_category_name_english',
            y = 'index')
plt.title('Top 10 product Categories Ordered', fontweight='bold')
plt.xlabel('Number of Orders')
plt.ylabel('Product Category')
# Out:
# Text(0, 0.5, 'Product Category')

# %% [markdown]
# LOWEST 10 items bought:

# %%
plt.subplot(212)
sns.barplot(data = worst_seller_p, x = 'product_category_name_english',
            y = 'index')
plt.title('Lowest 10 Product Categories Ordered', fontweight = 'bold')
plt.xlabel('Number of Orders')
plt.ylabel('Product Category')
# Out:
# Text(0, 0.5, 'Product Category')

# %% [markdown]
# Bed and bath products are the top products ordered followed by beauty products and housewares.
#
# Musical products have the lowest amount of products ordered, followed by flowers and children clothes.

# %% [markdown]
# WHICH ARE THE MOST COMMON PAYMENT TYPES?

# %%
payment_types = data['payment_type'].value_counts().reset_index() #count the number of different types of payment
print(payment_types)
# Out:
#          index  payment_type
# 0  credit_card         10319
# 1       boleto          2511
# 2      voucher           515
# 3   debit_card           368

# %% [markdown]
# WHICH ARE THE NUMBER OF ORDERS PER PAYMENT TYPE?

# %%
plt.subplot(121)
sns.barplot(data = payment_types, x = 'index', y = 'payment_type')
plt.title('Orders by Payment type')
plt.xlabel('Payment Type')
plt.ylabel('Number of Orders');

# %% [markdown]
# WHICH IS THE NUMBER OF ORDERS WITH NUMBER OF PAYMENT INSTALLMENTS?

# %%
plt.subplot(122)
sns.barplot(data = data['payment_installments'].value_counts().reset_index(), x = 'index', y = 'payment_installments')
plt.title('Count of Orders With Number of Payment Installments')
plt.xlabel('Number of Payment Installments')
plt.ylabel('Count of Orders');

# %% [markdown]
# RFM ANALYSIS:

# %% [markdown]
# We start with RECENCY, which is the time since a customer's last purchase. It is calculated by subtracting the customer's last shopping date from each shopping timestamp:

# %%
data['recency'] = print((max(data['order_purchase_timestamp']) - data['order_purchase_timestamp']))
# Out:
# 0        35 days 18:10:23
# 1        20 days 03:14:25
# 2        50 days 20:05:32
# 3         8 days 04:51:35
# 4         8 days 04:51:35
#                ...
# 13708    45 days 04:55:28
# 13709   113 days 18:15:13
# 13710   123 days 00:19:06
# 13711    48 days 16:24:28
# 13712    22 days 03:59:02
# Name: order_purchase_timestamp, Length: 13713, dtype: timedelta64[ns]

# %% [markdown]
# As we only want to know the days since a customer's last purchase, we could have used directly the variable 'order_date' that we initialized at the beginning of the project, but we noticed that it seems to round up the days by considering if the time of the purchase is close to the next day or not, so we are leaving both methods for sake of completeness:

# %%
data['recency'] = (max(data['order_date']) - data['order_date'])

# %% [markdown]
# Furthermore, for the customers who made more than one purchase we will only consider the most recent purchase:

# %%
data['recency'] = data.groupby(['customer_unique_id'], as_index=False)['recency'].transform('min')

# %% [markdown]
# As a last step we will calculate mean, standard deviation, minimum value and maximum value for recency (we will do the same with the other two components of RFM):

# %%
data['recency'] = data['recency'].dt.days

# %%
print('mean: ', data['recency'].mean())
print('std: ', data['recency'].std())
print('max: ', data['recency'].max())
print('min: ', data['recency'].min())
# Out:
# mean:  73.78378181287829
# std:  42.44889156457327
# max:  482
# min:  0

# %% [markdown]
# FREQUENCY: This is the total number of purchases of the customer. In a different way, it gives the frequency of purchases made by the customer. We just count the number of purchases per customer, obviously considering each customer's unique id as a parameter:

# %%
data['frequency'] = data.groupby(['customer_unique_id'], as_index=False)['order_id'].transform('count')

# %%
print('mean: ', data['frequency'].mean())
print('std: ', data['frequency'].std())
print('max: ', data['frequency'].max())
print('min: ', data['frequency'].min())
# Out:
# mean:  1.5852840370451395
# std:  1.2885963775263332
# max:  13
# min:  1

# %% [markdown]
# MONETARY: It is the total amount of money spent by the customer. It can be calculted by summing all the 'payment_values':

# %%
data['monetary'] = data.groupby(['customer_unique_id'], as_index=False)['payment_value'].transform('sum')

# %%
print('mean: ', data['monetary'].mean())
print('std: ', data['monetary'].std())
print('max: ', data['monetary'].max())
print('min: ', data['monetary'].min())
# Out:
# mean:  395.11181141982
# std:  1090.5970502209364
# max:  19457.04
# min:  10.71

# %% [markdown]
# As you can see in the computation of Frequency and Monetary, the columns of 'order_id' and 'payment_value' are replaced by the result of the computation (sum and count), even if in the putput they might not have the name changed.

# %% [markdown]
# We now want to create a first segmentation of the customers based on the RFM. To do this we are going to convert ther RFM scores to a single variable from 1 to 5. We are going to choose the cluster a customer will be assigned to based on the values of mean, std, min and max.

# %% [markdown]
# RECENCY

# %%
data['recency_score'] = ''

# %%
for i in data.index:
    if data['recency'][i] <= 20:
        data['recency_score'][i] = 5
    elif (data['recency'][i] > 20) and (data['recency'][i] <= 65): 
        data['recency_score'][i] = 4
    elif (data['recency'][i] > 65) and (data['recency'][i] <= 120):
        data['recency_score'][i] = 3
    elif (data['recency'][i] > 120) and (data['recency'][i] <= 200):
        data['recency_score'][i] = 2
    elif (data['recency'][i] > 200): 
        data['recency_score'][i] = 1
# Out:
# <ipython-input-186-17f41bb00f87>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['recency_score'][i] = 4
# <ipython-input-186-17f41bb00f87>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['recency_score'][i] = 5
# <ipython-input-186-17f41bb00f87>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['recency_score'][i] = 3
# <ipython-input-186-17f41bb00f87>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['recency_score'][i] = 2
# <ipython-input-186-17f41bb00f87>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['recency_score'][i] = 1

# %% [markdown]
# In this case, talking about recency, we know that the mean is 73 days, so we thought that giving 4 to those customers that haven't bought for 20-65 days was the best option. For the other intervals of time, we kept it quite large considering that the strandard deviation for this score is 42 days.

# %%
data
# Out:
#                                order_id                       customer_id  \
# 0      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 1      86674ccaee19790309333210917b2c7d  1b338293f35549b5e480b9a3d7bbf3cd
# 2      aee682982e18eb4714ce9f97b15af5e2  8858442ea4d5dc5bb9e118e8f728095d
# 3      d543201a9b42a1402ff97e65b439a48b  971bf8f42a9f8cb3ead257854905b454
# 4      d543201a9b42a1402ff97e65b439a48b  971bf8f42a9f8cb3ead257854905b454
# ...                                 ...                               ...
# 13708  493ba21a937e956c5e0e4e26c9f1b7f9  408d74d06be5d5140bb933f248de1342
# 13709  4a7cf245701068d38d441791b735e4bd  1d3b24ba06f2e3fa4bfa74fd70d2310f
# 13710  33f8dfc5a51063c31d7b12e9d43a45fc  8f7f4871646eb2fa410cc2d50b861317
# 13711  442a41b00a8a8bda35511fdf1eb65cc5  e42e2e8642f9c09100b6667e321c2811
# 13712  73d60420cd1a179b2d8887d538efe4c2  65d9213dfa004c17dc126503e106e4a3
#
#       order_status order_purchase_timestamp   order_approved_at  \
# 0        delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 1        delivered      2018-08-09 11:37:35 2018-08-09 14:35:19
# 2        delivered      2018-07-09 18:46:28 2018-07-11 03:45:45
# 3        delivered      2018-08-21 10:00:25 2018-08-21 10:50:54
# 4        delivered      2018-08-21 10:00:25 2018-08-21 10:50:54
# ...            ...                      ...                 ...
# 13708    delivered      2018-07-15 09:56:32 2018-07-16 13:30:36
# 13709    delivered      2018-05-07 20:36:47 2018-05-07 20:51:50
# 13710    delivered      2018-04-28 14:32:54 2018-04-28 14:53:18
# 13711     invoiced      2018-07-11 22:27:32 2018-07-11 22:45:43
# 13712    delivered      2018-08-07 10:52:58 2018-08-07 11:05:18
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 0              2018-07-26 14:31:00           2018-08-07 15:27:45
# 1              2018-08-10 14:34:00           2018-08-14 18:51:47
# 2              2018-07-11 15:01:00           2018-07-12 18:14:35
# 3              2018-08-22 15:21:00           2018-08-28 18:58:22
# 4              2018-08-22 15:21:00           2018-08-28 18:58:22
# ...                            ...                           ...
# 13708          2018-07-27 07:26:00           2018-08-02 18:06:41
# 13709          2018-05-08 15:04:00           2018-05-09 22:38:53
# 13710          2018-05-02 15:25:00           2018-05-03 23:51:56
# 13711          2018-07-11 22:45:43           2018-07-20 00:00:00
# 13712          2018-08-08 08:31:00           2018-08-22 17:02:23
#
#       order_estimated_delivery_date payment_type  payment_installments  ...  \
# 0                        2018-08-13       boleto                     1  ...
# 1                        2018-08-22  credit_card                     5  ...
# 2                        2018-07-18       boleto                     1  ...
# 3                        2018-09-10  credit_card                     2  ...
# 4                        2018-09-10  credit_card                     2  ...
# ...                             ...          ...                   ...  ...
# 13708                    2018-07-26       boleto                     1  ...
# 13709                    2018-05-17  credit_card                     1  ...
# 13710                    2018-05-14  credit_card                     1  ...
# 13711                    2018-07-20  credit_card                     1  ...
# 13712                    2018-09-04  credit_card                    10  ...
#
#        product_category_name product_name_lenght product_description_lenght  \
# 0                 perfumaria                  29                        178
# 1                 perfumaria                  29                        178
# 2                 perfumaria                  29                        178
# 3                 perfumaria                  29                        178
# 4                 perfumaria                  29                        178
# ...                      ...                 ...                        ...
# 13708      livros_importados                  53                         80
# 13709      livros_importados                  53                         80
# 13710      livros_importados                  53                         80
# 13711      livros_importados                  53                        568
# 13712      livros_importados                  57                       3694
#
#       product_category_name_english  order_date order_time recency frequency  \
# 0                         perfumery  2018-07-24   20:41:37      36         1
# 1                         perfumery  2018-08-09   11:37:35      20         1
# 2                         perfumery  2018-07-09   18:46:28      25         2
# 3                         perfumery  2018-08-21   10:00:25       8         2
# 4                         perfumery  2018-08-21   10:00:25       8         2
# ...                             ...         ...        ...     ...       ...
# 13708                books_imported  2018-07-15   09:56:32      45         1
# 13709                books_imported  2018-05-07   20:36:47     114         1
# 13710                books_imported  2018-04-28   14:32:54     123         1
# 13711                books_imported  2018-07-11   22:27:32      49         1
# 13712                books_imported  2018-08-07   10:52:58      22         1
#
#        monetary  recency_score
# 0        141.46              4
# 1        135.82              5
# 2        254.27              4
# 3        558.60              5
# 4        558.60              5
# ...         ...            ...
# 13708     27.39              4
# 13709     26.38              3
# 13710     26.38              2
# 13711     52.57              4
# 13712    804.96              4
#
# [13713 rows x 32 columns]

# %% [markdown]
# FREQUENCY

# %%
data['frequency_score'] = ''

# %%
for i in data.index:
    if data['frequency'][i] >= 9:
        data['frequency_score'][i] = 5
    elif (data['frequency'][i] > 7) and (data['frequency'][i] < 9):
        data['frequency_score'][i] = 4
    elif (data['frequency'][i] >= 5) and (data['frequency'][i] < 7):
        data['frequency_score'][i] = 3
    elif (data['frequency'][i] >= 2) and (data['frequency'][i] < 5):
        data['frequency_score'][i] = 2
    elif (data['frequency'][i] == 1):
        data['frequency_score'][i] = 1
# Out:
# <ipython-input-189-a3beab8c4ddf>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['frequency_score'][i] = 1
# <ipython-input-189-a3beab8c4ddf>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['frequency_score'][i] = 2
# <ipython-input-189-a3beab8c4ddf>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['frequency_score'][i] = 3
# <ipython-input-189-a3beab8c4ddf>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['frequency_score'][i] = 5
# <ipython-input-189-a3beab8c4ddf>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['frequency_score'][i] = 4

# %%
data
# Out:
#                                order_id                       customer_id  \
# 0      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 1      86674ccaee19790309333210917b2c7d  1b338293f35549b5e480b9a3d7bbf3cd
# 2      aee682982e18eb4714ce9f97b15af5e2  8858442ea4d5dc5bb9e118e8f728095d
# 3      d543201a9b42a1402ff97e65b439a48b  971bf8f42a9f8cb3ead257854905b454
# 4      d543201a9b42a1402ff97e65b439a48b  971bf8f42a9f8cb3ead257854905b454
# ...                                 ...                               ...
# 13708  493ba21a937e956c5e0e4e26c9f1b7f9  408d74d06be5d5140bb933f248de1342
# 13709  4a7cf245701068d38d441791b735e4bd  1d3b24ba06f2e3fa4bfa74fd70d2310f
# 13710  33f8dfc5a51063c31d7b12e9d43a45fc  8f7f4871646eb2fa410cc2d50b861317
# 13711  442a41b00a8a8bda35511fdf1eb65cc5  e42e2e8642f9c09100b6667e321c2811
# 13712  73d60420cd1a179b2d8887d538efe4c2  65d9213dfa004c17dc126503e106e4a3
#
#       order_status order_purchase_timestamp   order_approved_at  \
# 0        delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 1        delivered      2018-08-09 11:37:35 2018-08-09 14:35:19
# 2        delivered      2018-07-09 18:46:28 2018-07-11 03:45:45
# 3        delivered      2018-08-21 10:00:25 2018-08-21 10:50:54
# 4        delivered      2018-08-21 10:00:25 2018-08-21 10:50:54
# ...            ...                      ...                 ...
# 13708    delivered      2018-07-15 09:56:32 2018-07-16 13:30:36
# 13709    delivered      2018-05-07 20:36:47 2018-05-07 20:51:50
# 13710    delivered      2018-04-28 14:32:54 2018-04-28 14:53:18
# 13711     invoiced      2018-07-11 22:27:32 2018-07-11 22:45:43
# 13712    delivered      2018-08-07 10:52:58 2018-08-07 11:05:18
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 0              2018-07-26 14:31:00           2018-08-07 15:27:45
# 1              2018-08-10 14:34:00           2018-08-14 18:51:47
# 2              2018-07-11 15:01:00           2018-07-12 18:14:35
# 3              2018-08-22 15:21:00           2018-08-28 18:58:22
# 4              2018-08-22 15:21:00           2018-08-28 18:58:22
# ...                            ...                           ...
# 13708          2018-07-27 07:26:00           2018-08-02 18:06:41
# 13709          2018-05-08 15:04:00           2018-05-09 22:38:53
# 13710          2018-05-02 15:25:00           2018-05-03 23:51:56
# 13711          2018-07-11 22:45:43           2018-07-20 00:00:00
# 13712          2018-08-08 08:31:00           2018-08-22 17:02:23
#
#       order_estimated_delivery_date payment_type  payment_installments  ...  \
# 0                        2018-08-13       boleto                     1  ...
# 1                        2018-08-22  credit_card                     5  ...
# 2                        2018-07-18       boleto                     1  ...
# 3                        2018-09-10  credit_card                     2  ...
# 4                        2018-09-10  credit_card                     2  ...
# ...                             ...          ...                   ...  ...
# 13708                    2018-07-26       boleto                     1  ...
# 13709                    2018-05-17  credit_card                     1  ...
# 13710                    2018-05-14  credit_card                     1  ...
# 13711                    2018-07-20  credit_card                     1  ...
# 13712                    2018-09-04  credit_card                    10  ...
#
#        product_name_lenght product_description_lenght  \
# 0                       29                        178
# 1                       29                        178
# 2                       29                        178
# 3                       29                        178
# 4                       29                        178
# ...                    ...                        ...
# 13708                   53                         80
# 13709                   53                         80
# 13710                   53                         80
# 13711                   53                        568
# 13712                   57                       3694
#
#       product_category_name_english  order_date  order_time recency frequency  \
# 0                         perfumery  2018-07-24    20:41:37      36         1
# 1                         perfumery  2018-08-09    11:37:35      20         1
# 2                         perfumery  2018-07-09    18:46:28      25         2
# 3                         perfumery  2018-08-21    10:00:25       8         2
# 4                         perfumery  2018-08-21    10:00:25       8         2
# ...                             ...         ...         ...     ...       ...
# 13708                books_imported  2018-07-15    09:56:32      45         1
# 13709                books_imported  2018-05-07    20:36:47     114         1
# 13710                books_imported  2018-04-28    14:32:54     123         1
# 13711                books_imported  2018-07-11    22:27:32      49         1
# 13712                books_imported  2018-08-07    10:52:58      22         1
#
#       monetary  recency_score  frequency_score
# 0       141.46              4                1
# 1       135.82              5                1
# 2       254.27              4                2
# 3       558.60              5                2
# 4       558.60              5                2
# ...        ...            ...              ...
# 13708    27.39              4                1
# 13709    26.38              3                1
# 13710    26.38              2                1
# 13711    52.57              4                1
# 13712   804.96              4                1
#
# [13713 rows x 33 columns]

# %% [markdown]
# With frequency we have been a little bit more 'generous' because, considering that the maximum amount of items bought is 13 and that, on average, the items bought are between 1 anmd 2, we think that a customer who bought more than 9 items can be considered a customer of level 5

# %% [markdown]
# MONETARY

# %%
data['monetary_score'] = ''

# %%
for i in data.index:
    if data['monetary'][i] > 500:
        data['monetary_score'][i] = 5
    elif (data['monetary'][i] > 250) and (data['monetary'][i] <= 500):
        data['monetary_score'][i] = 4
    elif (data['monetary'][i] > 150) and (data['monetary'][i] <= 250):
        data['monetary_score'][i] = 3
    elif (data['monetary'][i] > 100) and (data['monetary'][i] <= 150):
        data['monetary_score'][i] = 2
    elif (data['monetary'][i] <= 100):
        data['monetary_score'][i] = 1
# Out:
# <ipython-input-192-38e36a3bc303>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['monetary_score'][i] = 2
# <ipython-input-192-38e36a3bc303>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['monetary_score'][i] = 4
# <ipython-input-192-38e36a3bc303>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['monetary_score'][i] = 5
# <ipython-input-192-38e36a3bc303>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['monetary_score'][i] = 3
# <ipython-input-192-38e36a3bc303>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['monetary_score'][i] = 1

# %%
data
# Out:
#                                order_id                       customer_id  \
# 0      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 1      86674ccaee19790309333210917b2c7d  1b338293f35549b5e480b9a3d7bbf3cd
# 2      aee682982e18eb4714ce9f97b15af5e2  8858442ea4d5dc5bb9e118e8f728095d
# 3      d543201a9b42a1402ff97e65b439a48b  971bf8f42a9f8cb3ead257854905b454
# 4      d543201a9b42a1402ff97e65b439a48b  971bf8f42a9f8cb3ead257854905b454
# ...                                 ...                               ...
# 13708  493ba21a937e956c5e0e4e26c9f1b7f9  408d74d06be5d5140bb933f248de1342
# 13709  4a7cf245701068d38d441791b735e4bd  1d3b24ba06f2e3fa4bfa74fd70d2310f
# 13710  33f8dfc5a51063c31d7b12e9d43a45fc  8f7f4871646eb2fa410cc2d50b861317
# 13711  442a41b00a8a8bda35511fdf1eb65cc5  e42e2e8642f9c09100b6667e321c2811
# 13712  73d60420cd1a179b2d8887d538efe4c2  65d9213dfa004c17dc126503e106e4a3
#
#       order_status order_purchase_timestamp   order_approved_at  \
# 0        delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 1        delivered      2018-08-09 11:37:35 2018-08-09 14:35:19
# 2        delivered      2018-07-09 18:46:28 2018-07-11 03:45:45
# 3        delivered      2018-08-21 10:00:25 2018-08-21 10:50:54
# 4        delivered      2018-08-21 10:00:25 2018-08-21 10:50:54
# ...            ...                      ...                 ...
# 13708    delivered      2018-07-15 09:56:32 2018-07-16 13:30:36
# 13709    delivered      2018-05-07 20:36:47 2018-05-07 20:51:50
# 13710    delivered      2018-04-28 14:32:54 2018-04-28 14:53:18
# 13711     invoiced      2018-07-11 22:27:32 2018-07-11 22:45:43
# 13712    delivered      2018-08-07 10:52:58 2018-08-07 11:05:18
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 0              2018-07-26 14:31:00           2018-08-07 15:27:45
# 1              2018-08-10 14:34:00           2018-08-14 18:51:47
# 2              2018-07-11 15:01:00           2018-07-12 18:14:35
# 3              2018-08-22 15:21:00           2018-08-28 18:58:22
# 4              2018-08-22 15:21:00           2018-08-28 18:58:22
# ...                            ...                           ...
# 13708          2018-07-27 07:26:00           2018-08-02 18:06:41
# 13709          2018-05-08 15:04:00           2018-05-09 22:38:53
# 13710          2018-05-02 15:25:00           2018-05-03 23:51:56
# 13711          2018-07-11 22:45:43           2018-07-20 00:00:00
# 13712          2018-08-08 08:31:00           2018-08-22 17:02:23
#
#       order_estimated_delivery_date payment_type  payment_installments  ...  \
# 0                        2018-08-13       boleto                     1  ...
# 1                        2018-08-22  credit_card                     5  ...
# 2                        2018-07-18       boleto                     1  ...
# 3                        2018-09-10  credit_card                     2  ...
# 4                        2018-09-10  credit_card                     2  ...
# ...                             ...          ...                   ...  ...
# 13708                    2018-07-26       boleto                     1  ...
# 13709                    2018-05-17  credit_card                     1  ...
# 13710                    2018-05-14  credit_card                     1  ...
# 13711                    2018-07-20  credit_card                     1  ...
# 13712                    2018-09-04  credit_card                    10  ...
#
#        product_description_lenght product_category_name_english  order_date  \
# 0                             178                     perfumery  2018-07-24
# 1                             178                     perfumery  2018-08-09
# 2                             178                     perfumery  2018-07-09
# 3                             178                     perfumery  2018-08-21
# 4                             178                     perfumery  2018-08-21
# ...                           ...                           ...         ...
# 13708                          80                books_imported  2018-07-15
# 13709                          80                books_imported  2018-05-07
# 13710                          80                books_imported  2018-04-28
# 13711                         568                books_imported  2018-07-11
# 13712                        3694                books_imported  2018-08-07
#
#       order_time  recency frequency monetary recency_score  frequency_score  \
# 0       20:41:37       36         1   141.46             4                1
# 1       11:37:35       20         1   135.82             5                1
# 2       18:46:28       25         2   254.27             4                2
# 3       10:00:25        8         2   558.60             5                2
# 4       10:00:25        8         2   558.60             5                2
# ...          ...      ...       ...      ...           ...              ...
# 13708   09:56:32       45         1    27.39             4                1
# 13709   20:36:47      114         1    26.38             3                1
# 13710   14:32:54      123         1    26.38             2                1
# 13711   22:27:32       49         1    52.57             4                1
# 13712   10:52:58       22         1   804.96             4                1
#
#        monetary_score
# 0                   2
# 1                   2
# 2                   4
# 3                   5
# 4                   5
# ...               ...
# 13708               1
# 13709               1
# 13710               1
# 13711               1
# 13712               5
#
# [13713 rows x 34 columns]

# %% [markdown]
# We are now going to create columns in order to group all the scores. Then, we extracted from the original dataset only the columns of interest so that we can have a better visualization, keeping only the customer id.

# %%
#Recency:
data["recency_score"] = pd.qcut(data['recency'], 5, labels=[5, 4, 3, 2, 1])
#Frequency:
data["frequency_score"] = pd.qcut(data["frequency"].rank(method="first"), 5, labels=[1, 2, 3, 4, 5])
#Monetary:
data["monetary_score"]= pd.qcut(data["monetary"],5,labels=[1,2,3,4,5])

rfm_data = data[[ 'recency', 'frequency', 'monetary', 'recency_score', 'frequency_score', 'monetary_score']]

rfm_data.head()
# Out:
#    recency  frequency  monetary recency_score frequency_score monetary_score
# 0       36          1    141.46             4               1              3
# 1       20          1    135.82             5               1              3
# 2       25          2    254.27             5               4              4
# 3        8          2    558.60             5               4              5
# 4        8          2    558.60             5               4              5

# %%
rfm = rfm_data[['recency', 'frequency', 'monetary']]

# %%
# Standardizing the features
scaler = StandardScaler()
rfm_std = scaler.fit_transform(rfm)

# %% [markdown]
# K Means Clustering

# %%
# Importing libraries for K-means algorithm and performance measurments

# Using elbow method to find out optimal k value with WCSS score
# Creating empty list to insert values
WCSS = []

# Using a for function to fill the list with the WCSS scores
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state=42)
    kmeans.fit(rfm_std)
    WCSS.append(kmeans.inertia_)

kmeans = KMeans(n_clusters=3, init='k-means++', random_state=42)
# Use fit_predict to cluster the dataset
km_clusters = kmeans.fit_predict(rfm_std)

rfm_std_cl = pd.DataFrame(rfm_std, columns=rfm.columns, index=rfm.index)
rfm_std_cl['cluster'] = km_clusters

# %% [markdown]
# Plotting the Elbow method graph

# %%
# Plotting the Elbow method graph
plt.figure()
plt.plot(range(1, 11), WCSS, marker='o', label='line with marker')
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
kmeans = KMeans(n_clusters=4, init='k-means++', random_state=42)
# Use fit_predict to cluster the dataset
km_clusters = kmeans.fit_predict(rfm_std)

rfm_std_cl = pd.DataFrame(rfm_std, columns=rfm.columns, index=rfm.index)
rfm_std_cl['cluster'] = km_clusters

# Visualising the clusters (4 clusters according to the Elbow method)
plt.scatter(rfm_std[km_clusters == 0, 0], rfm_std[km_clusters ==
            0, 1], s=30, c='orange', label='Cluster 1')
plt.scatter(rfm_std[km_clusters == 1, 0], rfm_std[km_clusters ==
            1, 1], s=30, c='yellow', label='Cluster 2')
plt.scatter(rfm_std[km_clusters == 2, 0], rfm_std[km_clusters ==
            2, 1], s=30, c='brown', label='Cluster 3')
plt.scatter(rfm_std[km_clusters == 3, 0], rfm_std[km_clusters ==
            3, 1], s=30, c='purple', label='Cluster 4')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[
            :, 1], s=70, c='black', label='Centroids')
plt.title('Clusters of customers')
plt.legend()
plt.show()

# %%
display(rfm_std_cl)
# Out:
#         recency  frequency  monetary  cluster
# 0     -0.890133  -0.454219 -0.232589        0
# 1     -1.267071  -0.454219 -0.237761        0
# 2     -1.149278   0.321847 -0.129147        0
# 3     -1.549774   0.321847  0.149913        0
# 4     -1.549774   0.321847  0.149913        0
# ...         ...        ...       ...      ...
# 13708 -0.678106  -0.454219 -0.337187        0
# 13709  0.947438  -0.454219 -0.338113        2
# 13710  1.159465  -0.454219 -0.338113        2
# 13711 -0.583871  -0.454219 -0.314098        0
# 13712 -1.219953  -0.454219  0.375815        0
#
# [13713 rows x 4 columns]

# %%
#3D visualization of the graph above
fig=plt.figure(figsize=(15,8))
gr= fig.add_subplot(111, projection='3d')
gr.scatter(rfm_std[km_clusters == 0, 0], rfm_std[km_clusters ==
            0, 1], rfm_std[km_clusters == 0, 2], s=30, c='orange', label='Cluster 1')
gr.scatter(rfm_std[km_clusters == 1, 0], rfm_std[km_clusters ==
            1, 1], rfm_std[km_clusters == 1, 2],s=30, c='yellow', label='Cluster 2')
gr.scatter(rfm_std[km_clusters == 2, 0], rfm_std[km_clusters ==
            2, 1], rfm_std[km_clusters == 2, 2],s=30, c='brown', label='Cluster 3')
gr.scatter(rfm_std[km_clusters == 3, 0], rfm_std[km_clusters ==
            3, 1], rfm_std[km_clusters == 3, 2],s=30, c='purple', label='Cluster 4')
gr.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[
            :, 1], kmeans.cluster_centers_[  :, 2],s=70, c='black', label='Centroids')
gr.set_xlabel('Recency')
gr.set_ylabel('Monetary Value')
gr.set_zlabel('Frequency')
gr.legend()
plt.title('Kmeans Clustering')
plt.show()

# %% [markdown]
# Visualizing the clusters

# %% [markdown]
# Calculating cluster validation metrics (silhouette score, calinski harabasz score, davies bouldin score)

# %%
kmeans_s = silhouette_score(rfm_std, kmeans.labels_, metric='euclidean')
kmeans_c = calinski_harabasz_score(rfm_std, kmeans.labels_)
kmeans_d = davies_bouldin_score(rfm_std, km_clusters)
print('Silhouette Score for K-Means:', kmeans_s)
print('Calinski Harabasz Score for K-Means:', kmeans_c)
print('Davies Bouldin Score for K-Means:', kmeans_d)
# Out:
# Silhouette Score for K-Means: 0.4971721012637513
# Calinski Harabasz Score for K-Means: 10853.1923061226
# Davies Bouldin Score for K-Means: 0.7457922472871862

# %% [markdown]
# Hierarchical Clustering

# %%
#Plotting the dendogram
plt.figure()
dendrogram = sch.dendrogram(sch.linkage(rfm_std, method='ward'))
plt.title('Dendrogram')
plt.xlabel('Customers')
plt.ylabel('Euclidean distances')
plt.xticks([])
plt.show()

# %%
# Fitting Hierarchical Clustering to the dataset
hc = AgglomerativeClustering(
    n_clusters=4, affinity='euclidean', linkage='ward')
hc_clusters = hc.fit_predict(rfm_std)
rfm_std_hc = pd.DataFrame(rfm_std, columns=rfm.columns, index=rfm.index)
rfm_std_hc['cluster'] = hc_clusters
rfm_std_hc
# Out:
#         recency  frequency  monetary  cluster
# 0     -0.890133  -0.454219 -0.232589        2
# 1     -1.267071  -0.454219 -0.237761        2
# 2     -1.149278   0.321847 -0.129147        2
# 3     -1.549774   0.321847  0.149913        2
# 4     -1.549774   0.321847  0.149913        2
# ...         ...        ...       ...      ...
# 13708 -0.678106  -0.454219 -0.337187        2
# 13709  0.947438  -0.454219 -0.338113        3
# 13710  1.159465  -0.454219 -0.338113        3
# 13711 -0.583871  -0.454219 -0.314098        2
# 13712 -1.219953  -0.454219  0.375815        2
#
# [13713 rows x 4 columns]

# %%
# Visualising the clusters (4 clusters according to the Dendogram)
plt.figure()
plt.scatter(rfm_std[hc_clusters == 0, 0], rfm_std[hc_clusters == 0, 1], s = 30, c = 'orange', label = 'Cluster 1')
plt.scatter(rfm_std[hc_clusters == 1, 0], rfm_std[hc_clusters == 1, 1], s = 30, c = 'yellow', label = 'Cluster 2')
plt.scatter(rfm_std[hc_clusters == 2, 0], rfm_std[hc_clusters == 2, 1], s = 30, c = 'brown', label = 'Cluster 3')
plt.scatter(rfm_std[hc_clusters == 3, 0], rfm_std[hc_clusters == 3, 1], s = 30, c = 'red', label = 'Cluster 4')
plt.title('Clusters of customers')
plt.legend()
plt.show()

# %%
#3D visualization of the graph above
fig=plt.figure(figsize=(15,8))
gr= fig.add_subplot(111, projection='3d')
gr.scatter(rfm_std[hc_clusters == 0, 0], rfm_std[hc_clusters == 0, 1], rfm_std[hc_clusters == 0, 2],s = 30, c = 'orange', label = 'Cluster 1')
gr.scatter(rfm_std[hc_clusters == 1, 0], rfm_std[hc_clusters == 1, 1], rfm_std[hc_clusters == 1, 2],s = 30, c = 'yellow', label = 'Cluster 2')
gr.scatter(rfm_std[hc_clusters == 2, 0], rfm_std[hc_clusters == 2, 1], rfm_std[hc_clusters == 2, 2],s = 30, c = 'brown', label = 'Cluster 3')
gr.scatter(rfm_std[hc_clusters == 3, 0], rfm_std[hc_clusters == 3, 1], rfm_std[hc_clusters == 3, 2],s = 30, c = 'red', label = 'Cluster 4')
gr.set_xlabel('Recency')
gr.set_ylabel('Monetary Value')
gr.set_zlabel('Frequency')
gr.legend()
plt.title('Hierarchical Clustering')
plt.show()

# %%
# Calculating cluster validation metrics
hierarchical_s = silhouette_score(
    rfm_std, hc.labels_, metric='euclidean')
hierarchical_c = calinski_harabasz_score(rfm_std, hc.labels_,)
hierarchical_d = davies_bouldin_score(rfm_std, hc_clusters)
print('Silhouette Score for Hierarchical:', hierarchical_s)
print('Calinski Harabasz Score for Hierarchical:', hierarchical_c)
print('Davies Bouldin Score for Hierarchical:', hierarchical_d)
# Out:
# Silhouette Score for Hierarchical: 0.4571527793212163
# Calinski Harabasz Score for Hierarchical: 8814.023577730359
# Davies Bouldin Score for Hierarchical: 0.8257241755670588

# %% [markdown]
# PCA

# %%
wcss = []
for i in range(1,11):
   model = KMeans(n_clusters = i, init = "k-means++")
   model.fit(rfm_std)
   wcss.append(model.inertia_)
plt.figure(figsize=(10,10))
plt.plot(range(1,11), wcss, marker='o', label='line with marker')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
pca = PCA(3)
data2 = pca.fit_transform(rfm_std)
rfm_std_pca1 = pd.DataFrame(data2)
type(rfm_std_pca1)
#rfm_std_pca1['cluster1'] = data2[0]
#rfm_std_pca1['cluster2'] = data2[1].array.reshape(1,1)
#rfm_std_pca1['cluster3'] = data2[2].array.reshape(1,1)
#rfm_std_pca1
# Out:
# pandas.core.frame.DataFrame

# %%
plt.figure(figsize=(10,10))
var = np.round(pca.explained_variance_ratio_*100, decimals = 1)
lbls = [str(x) for x in range(1,len(var)+1)]
plt.bar(x=range(1,len(var)+1), height = var, tick_label = lbls)
plt.show()

# %%
model = KMeans(n_clusters = 4, init = "k-means++")
label = model.fit_predict(data2)
plt.figure(figsize=(10,10))
uniq = np.unique(label)
for i in uniq:
   plt.scatter(data2[label == i , 0] , data2[label == i , 1] , label = i)   
plt.scatter(model.cluster_centers_[:, 0], model.cluster_centers_[
            :, 1], s=70, c='black', label='Centroids')
#This is done to find the centroid for each clusters.
plt.legend()
plt.show()

# %%
pca_s = silhouette_score(rfm_std, model.labels_, metric='euclidean')
pca_c = calinski_harabasz_score(rfm_std, model.labels_)
pca_d = davies_bouldin_score(rfm_std, label)
print('Silhouette Score for PCA:', pca_s)
print('Calinski Harabasz Score for PCA:', pca_c)
print('Davies Bouldin Score for PCA:', pca_d)
# Out:
# Silhouette Score for PCA: 0.4971764001637761
# Calinski Harabasz Score for PCA: 10853.14240879579
# Davies Bouldin Score for PCA: 0.7463424287838839

# %%
df = pd.DataFrame()
dataallcl=[[hierarchical_s, hierarchical_c, hierarchical_d],[pca_s, pca_c, pca_d ],[kmeans_s, kmeans_c, kmeans_d]]
df = pd.DataFrame(dataallcl,columns=['Silhouette Score', 'Calinski Harabasz Score','Davies Bouldin Score'])
methods = ['Hierarchical','PCA','K-Means']
df['Method'] = methods

display(df)
# Out:
#    Silhouette Score  Calinski Harabasz Score  Davies Bouldin Score  \
# 0          0.457153              8814.023578              0.825724
# 1          0.497176             10853.142409              0.746342
# 2          0.497172             10853.192306              0.745792
#
#          Method
# 0  Hierarchical
# 1           PCA
# 2       K-Means

# %%
plt.figure(figsize=(10,7))
a = sns.barplot(x=df.index, y='Silhouette Score', data=df, palette='inferno')
a.set_xticklabels(['Hierarchical', 'PCA', 'Kmeans'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,7))
a = sns.barplot(x=df.index, y='Calinski Harabasz Score', data=df, palette='inferno')
a.set_xticklabels(['Hierarchical', 'PCA', 'Kmeans'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,7))
a = sns.barplot(x=df.index, y='Davies Bouldin Score', data=df, palette='inferno')
a.set_xticklabels(['Hierarchical', 'PCA', 'Kmeans'])
plt.xticks(rotation=90)
plt.show()

# %%
# mediana, media, massimo minimo e grandezza di un clusteer

# %%
clust_assign = rfm_std_cl.groupby('cluster').count()

# %%
clust_assign
# Out:
#          recency  frequency  monetary
# cluster
# 0           6365       6365      6365
# 1            893        893       893
# 2           6339       6339      6339
# 3            116        116       116

# %%
medianrecencykm=rfm_std_cl.groupby("cluster")[["recency"]].median()
medianrecencykm
# Out:
#           recency
# cluster
# 0       -0.913692
# 1        0.170004
# 2        0.876762
# 3        0.523383

# %%
medianfrequencykm = rfm_std_cl.groupby("cluster")[["frequency"]].median()
medianfrequencykm
# Out:
#          frequency
# cluster
# 0        -0.454219
# 1         2.650047
# 2        -0.454219
# 3         3.426113

# %%
medianmonetarykm = rfm_std_cl.groupby("cluster")[["monetary"]].median()
medianmonetarykm
# Out:
#          monetary
# cluster
# 0       -0.245968
# 1        0.780342
# 2       -0.237046
# 3        7.073015

# %%
medianfrequencykm['monetary']=medianmonetarykm['monetary']
medianfrequencykm['recency']=medianrecencykm['recency']
medianfrequencykm
# Out:
#          frequency  monetary   recency
# cluster
# 0        -0.454219 -0.245968 -0.913692
# 1         2.650047  0.780342  0.170004
# 2        -0.454219 -0.237046  0.876762
# 3         3.426113  7.073015  0.523383

# %% [markdown]
# The dataframe above shows the median in each cluster in the Kmeans method for recency,monetary and frequency values

# %%
boxplot = medianfrequencykm.boxplot(column=['frequency', 'monetary', 'recency'])

# %%
meanrecencykm=rfm_std_cl.groupby("cluster")[["recency"]].mean()
meanrecencykm
# Out:
#           recency
# cluster
# 0       -0.872426
# 1        0.080202
# 2        0.857711
# 3        0.382234

# %%
meanfrequencykm=rfm_std_cl.groupby("cluster")[["frequency"]].mean()
meanfrequencykm
# Out:
#          frequency
# cluster
# 0        -0.239871
# 1         2.580522
# 2        -0.216221
# 3         5.112051

# %%
meanmonetarykm=rfm_std_cl.groupby("cluster")[["monetary"]].mean()
meanmonetarykm
# Out:
#          monetary
# cluster
# 0       -0.163617
# 1        1.119887
# 2       -0.148713
# 3        8.483272

# %%
meanfrequencykm['monetary']=meanmonetarykm['monetary']
meanfrequencykm['recency']=meanrecencykm['recency']
meanfrequencykm
# Out:
#          frequency  monetary   recency
# cluster
# 0        -0.239871 -0.163617 -0.872426
# 1         2.580522  1.119887  0.080202
# 2        -0.216221 -0.148713  0.857711
# 3         5.112051  8.483272  0.382234

# %%
boxplot = meanfrequencykm.boxplot(column=['frequency', 'monetary', 'recency'])

# %%
minmonetarykm=rfm_std_cl.groupby("cluster")[["monetary"]].min()
minmonetarykm
# Out:
#          monetary
# cluster
# 0       -0.352482
# 1       -0.317692
# 2       -0.350465
# 3        5.092120

# %%
minrecencykm=rfm_std_cl.groupby("cluster")[["recency"]].min()
minrecencykm
# Out:
#           recency
# cluster
# 0       -1.738243
# 1       -1.620450
# 2       -0.018465
# 3       -0.984367

# %%
minfrequencykm=rfm_std_cl.groupby("cluster")[["frequency"]].min()
minfrequencykm
# Out:
#          frequency
# cluster
# 0        -0.454219
# 1         0.321847
# 2        -0.454219
# 3         1.873980

# %%
minfrequencykm['monetary']=minmonetarykm['monetary']
minfrequencykm['recency']=minrecencykm['recency']
minfrequencykm
# Out:
#          frequency  monetary   recency
# cluster
# 0        -0.454219 -0.352482 -1.738243
# 1         0.321847 -0.317692 -1.620450
# 2        -0.454219 -0.350465 -0.018465
# 3         1.873980  5.092120 -0.984367

# %%
boxplot = minfrequencykm.boxplot(column=['frequency', 'monetary', 'recency'])

# %%
maxfrequencykm=rfm_std_cl.groupby("cluster")[["frequency"]].max()
maxfrequencykm
# Out:
#          frequency
# cluster
# 0         1.097914
# 1         8.082512
# 2         1.097914
# 3         8.858579

# %%
maxmonetarykm=rfm_std_cl.groupby("cluster")[["monetary"]].max()
maxmonetarykm
# Out:
#           monetary
# cluster
# 0         2.557617
# 1         5.609213
# 2         2.580890
# 3        17.479071

# %%
maxrecencykm=rfm_std_cl.groupby("cluster")[["recency"]].max()
maxrecencykm
# Out:
#           recency
# cluster
# 0       -0.018465
# 1        2.549423
# 2        9.617003
# 3        1.536403

# %%
maxfrequencykm['monetary']=maxmonetarykm['monetary']
maxfrequencykm['recency']=maxrecencykm['recency']
maxfrequencykm
# Out:
#          frequency   monetary   recency
# cluster
# 0         1.097914   2.557617 -0.018465
# 1         8.082512   5.609213  2.549423
# 2         1.097914   2.580890  9.617003
# 3         8.858579  17.479071  1.536403

# %%
boxplot = maxfrequencykm.boxplot(column=['frequency', 'monetary', 'recency'])

# %%
clust_assign1 = rfm_std_hc.groupby('cluster').count()

# %%
clust_assign1
# Out:
#          recency  frequency  monetary
# cluster
# 0            239        239       239
# 1            977        977       977
# 2           8157       8157      8157
# 3           4340       4340      4340

# %%
medianmonetaryhc = rfm_std_hc.groupby("cluster")[["monetary"]].median()
medianmonetaryhc
# Out:
#          monetary
# cluster
# 0        5.092120
# 1        0.484457
# 2       -0.240631
# 3       -0.247196

# %%
medianrecencyhc= rfm_std_hc.groupby("cluster")[["recency"]].median()
medianrecencyhc
# Out:
#           recency
# cluster
# 0        0.594059
# 1        0.523383
# 2       -0.748781
# 3        1.041672

# %%
medianfrequencyhc= rfm_std_hc.groupby("cluster")[["frequency"]].median()
medianfrequencyhc
# Out:
#          frequency
# cluster
# 0         3.426113
# 1         1.873980
# 2        -0.454219
# 3        -0.454219

# %%
medianfrequencyhc['monetary']= medianmonetaryhc['monetary']
medianfrequencyhc['recency']=medianrecencyhc['recency']
medianfrequencyhc
# Out:
#          frequency  monetary   recency
# cluster
# 0         3.426113  5.092120  0.594059
# 1         1.873980  0.484457  0.523383
# 2        -0.454219 -0.240631 -0.748781
# 3        -0.454219 -0.247196  1.041672

# %%
boxplot = medianfrequencyhc.boxplot(column=['frequency', 'monetary', 'recency'])

# %%
meanmonetaryhc = rfm_std_hc.groupby("cluster")[["monetary"]].mean()
meanmonetaryhc
# Out:
#          monetary
# cluster
# 0        5.937284
# 1        0.571815
# 2       -0.145369
# 3       -0.182465

# %%
meanrecencyhc = rfm_std_hc.groupby("cluster")[["recency"]].mean()
meanrecencyhc
# Out:
#           recency
# cluster
# 0        0.484940
# 1        0.354615
# 2       -0.641487
# 3        1.099136

# %%
meanfrequencyhc = rfm_std_hc.groupby("cluster")[["frequency"]].mean()
meanfrequencyhc
# Out:
#          frequency
# cluster
# 0         4.124248
# 1         2.127373
# 2        -0.220553
# 3        -0.291496

# %%
meanfrequencyhc['monetary']= meanmonetaryhc['monetary']
meanfrequencyhc['recency']=meanrecencyhc['recency']
meanfrequencyhc
# Out:
#          frequency  monetary   recency
# cluster
# 0         4.124248  5.937284  0.484940
# 1         2.127373  0.571815  0.354615
# 2        -0.220553 -0.145369 -0.641487
# 3        -0.291496 -0.182465  1.099136

# %%
boxplot = meanfrequencyhc.boxplot(column=['frequency', 'monetary', 'recency'])

# %%
minmonetaryhc = rfm_std_hc.groupby("cluster")[["monetary"]].min()
minmonetaryhc
# Out:
#          monetary
# cluster
# 0        2.322783
# 1       -0.350465
# 2       -0.352482
# 3       -0.349117

# %%
minfrequencyhc = rfm_std_hc.groupby("cluster")[["frequency"]].min()
minfrequencyhc
# Out:
#          frequency
# cluster
# 0         0.321847
# 1         1.097914
# 2        -0.454219
# 3        -0.454219

# %%
minrecencyhc = rfm_std_hc.groupby("cluster")[["recency"]].min()
minrecencyhc
# Out:
#           recency
# cluster
# 0       -1.384864
# 1       -1.620450
# 2       -1.738243
# 3        0.429149

# %%
minfrequencyhc['monetary']= minmonetaryhc['monetary']
minfrequencyhc['recency']=minrecencyhc['recency']
minfrequencyhc
# Out:
#          frequency  monetary   recency
# cluster
# 0         0.321847  2.322783 -1.384864
# 1         1.097914 -0.350465 -1.620450
# 2        -0.454219 -0.352482 -1.738243
# 3        -0.454219 -0.349117  0.429149

# %%
boxplotminhc = minfrequencyhc.boxplot(column=['frequency', 'monetary', 'recency'])

# %%
maxrecencyhc = rfm_std_hc.groupby("cluster")[["recency"]].max()
maxrecencyhc
# Out:
#           recency
# cluster
# 0        2.549423
# 1        1.984016
# 2        1.512844
# 3        9.617003

# %%
maxmonetaryhc = rfm_std_hc.groupby("cluster")[["monetary"]].max()
maxmonetaryhc
# Out:
#           monetary
# cluster
# 0        17.479071
# 1         2.448141
# 2         3.686967
# 3         1.515746

# %%
maxfrequencyhc = rfm_std_hc.groupby("cluster")[["frequency"]].max()
maxfrequencyhc
# Out:
#          frequency
# cluster
# 0         8.858579
# 1         5.754313
# 2         1.873980
# 3         0.321847

# %%
maxfrequencyhc['monetary']= maxmonetaryhc['monetary']
maxfrequencyhc['recency']=maxrecencyhc['recency']
maxfrequencyhc
# Out:
#          frequency   monetary   recency
# cluster
# 0         8.858579  17.479071  2.549423
# 1         5.754313   2.448141  1.984016
# 2         1.873980   3.686967  1.512844
# 3         0.321847   1.515746  9.617003

# %%
boxplotmaxhc = maxfrequencyhc.boxplot(column=['frequency', 'monetary', 'recency'])
